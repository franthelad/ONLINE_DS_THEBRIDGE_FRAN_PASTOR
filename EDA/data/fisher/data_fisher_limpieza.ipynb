# %%
import pandas as pd

# %%
df_fisher = pd.read_csv('./fischer_game_info.csv')
df_fisher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   game_id                827 non-null    object
#  1   game_order             827 non-null    int64
#  2   event                  827 non-null    object
#  3   site                   827 non-null    object
#  4   date_played            827 non-null    object
#  5   round                  827 non-null    object
#  6   white                  827 non-null    object
#  7   black                  827 non-null    object
#  8   result                 827 non-null    object
#  9   white_elo              72 non-null     float64
#  10  black_elo              72 non-null     float64
#  11  winner                 827 non-null    object
#  12  winner_elo             43 non-null     float64
#  13  loser                  827 non-null    object
#  14  loser_elo              43 non-null     float64
#  15  winner_loser_elo_diff  827 non-null    int64
#  16  eco                    827 non-null    object
#  17  date_created           827 non-null    object
#  18  file_name              827 non-null    object
# dtypes: float64(4), int64(2), object(13)
# memory usage: 122.9+ KB

# %%
df_fisher.drop(columns= ['game_id', 'game_order', 'round', 'winner_elo', 'loser_elo', 'winner_loser_elo_diff', 'eco', 'date_created', 'file_name'], inplace= True)
df_fisher.head()
# Out:
#      event site date_played                  white                  black  \
# 0  USA-chJ    ?  1955.??.??           Thomason, J.  Fischer, Robert James
# 1  USA-chJ    ?  1955.??.??  Fischer, Robert James             Warner, K.
# 2  USA-chJ    ?  1955.??.??  Fischer, Robert James        Pupols, Viktors
# 3  USA-chJ    ?  1955.??.??  Fischer, Robert James               Ames, D.
# 4  USA-chJ    ?  1955.??.??            Whisler, W.  Fischer, Robert James
#
#     result  white_elo  black_elo                 winner                  loser
# 0      0-1        NaN        NaN  Fischer, Robert James           Thomason, J.
# 1      0-1        NaN        NaN             Warner, K.  Fischer, Robert James
# 2      0-1        NaN        NaN        Pupols, Viktors  Fischer, Robert James
# 3  1/2-1/2        NaN        NaN                   draw                   draw
# 4  1/2-1/2        NaN        NaN                   draw                   draw

# %%
df_fisher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   event        827 non-null    object
#  1   site         827 non-null    object
#  2   date_played  827 non-null    object
#  3   white        827 non-null    object
#  4   black        827 non-null    object
#  5   result       827 non-null    object
#  6   white_elo    72 non-null     float64
#  7   black_elo    72 non-null     float64
#  8   winner       827 non-null    object
#  9   loser        827 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 64.7+ KB

# %%
df_fisher.head(50)
# Out:
#                  event         site date_played                       white  \
# 0              USA-chJ            ?  1955.??.??                Thomason, J.
# 1              USA-chJ            ?  1955.??.??       Fischer, Robert James
# 2              USA-chJ            ?  1955.??.??       Fischer, Robert James
# 3              USA-chJ            ?  1955.??.??       Fischer, Robert James
# 4              USA-chJ            ?  1955.??.??                 Whisler, W.
# 5           Havana sim       Havana  1956.??.??       Fischer, Robert James
# 6               CAN-op     Montreal  1956.??.??       Fischer, Robert James
# 7               CAN-op     Montreal  1956.??.??       Fischer, Robert James
# 8               CAN-op     Montreal  1956.??.??       Fischer, Robert James
# 9               CAN-op     Montreal  1956.??.??        Anderson, Frank Ross
# 10              CAN-op     Montreal  1956.??.??               Sobel, Robert
# 11              CAN-op     Montreal  1956.??.??                    Walz, W.
# 10       Fischer, Robert James      1-0        NaN        NaN
# 11       Fischer, Robert James      0-1        NaN        NaN
# 12       Fischer, Robert James      0-1        NaN        NaN
# 13       Fischer, Robert James  1/2-1/2        NaN        NaN
# 14                  Pavey, Max      0-1        NaN        NaN
# 15                    Vine, K.  1/2-1/2        NaN        NaN
# 16       Fischer, Robert James      0-1        NaN        NaN
# 17       Fischer, Robert James      1-0        NaN        NaN
# 18       Fischer, Robert James      0-1        NaN        NaN
# 19                   Baron, S.      1-0        NaN        NaN
# 20       Fischer, Robert James      1-0        NaN        NaN
# 21       Fischer, Robert James      1-0        NaN        NaN
# 22       Fischer, Robert James      1-0        NaN        NaN
# 23       Hearst, Eliot Sanford      0-1        NaN        NaN
# 24       Fischer, Robert James  1/2-1/2        NaN        NaN
# 25    Bernstein, Sidney Norman  1/2-1/2        NaN        NaN
# 26          Mednis, Edmar John  1/2-1/2        NaN        NaN
# 27                  Pavey, Max  1/2-1/2        NaN        NaN
# 28            Seidman, Herbert      1-0        NaN        NaN
# 29                Nash, Edmund      0-1        NaN        NaN
# 30       Fischer, Robert James      0-1        NaN        NaN
# 31  Santasiere, Anthony Edward  1/2-1/2        NaN        NaN
# 32       Fischer, Robert James      0-1        NaN        NaN
# 33                 Stevens, W.  1/2-1/2        NaN        NaN
# 34       Fischer, Robert James  1/2-1/2        NaN        NaN
# 35            Lapiken, Peter P      1-0        NaN        NaN
# 36                   Gross, H.  1/2-1/2        NaN        NaN
# 37       Fischer, Robert James      0-1        NaN        NaN
# 38       Fischer, Robert James  1/2-1/2        NaN        NaN
# 39             Popovych, Orest      1-0        NaN        NaN
# 40            Popel, Stephan A  1/2-1/2        NaN        NaN
# 41       Fischer, Robert James  1/2-1/2        NaN        NaN
# 42       Fischer, Robert James      0-1        NaN        NaN
# 43       Fischer, Robert James      0-1        NaN        NaN
# 44       Fischer, Robert James      0-1        NaN        NaN
# 45       Fischer, Robert James      0-1        NaN        NaN
# 46                Hurttlen, N.  1/2-1/2        NaN        NaN
# 47         Di Camillo, Attilio      1-0        NaN        NaN
# 48       Fischer, Robert James  1/2-1/2        NaN        NaN
# 49              Green, Matthew      1-0        NaN        NaN
#
#                       winner                      loser
# 0      Fischer, Robert James               Thomason, J.
# 1                 Warner, K.      Fischer, Robert James
# 2            Pupols, Viktors      Fischer, Robert James
# 3                       draw                       draw
# 4                       draw                       draw
# 5                       draw                       draw
# 6               Fox, Maurice      Fischer, Robert James
# 7                       draw                       draw
# 8      Fischer, Robert James                  Sharp, C.
# 9                       draw                       draw
# 10             Sobel, Robert      Fischer, Robert James
# 11     Fischer, Robert James                   Walz, W.
# 12     Fischer, Robert James   Bernstein, Sidney Norman
# 13                      draw                       draw
# 14                Pavey, Max      Fischer, Robert James
# 15                      draw                       draw
# 16     Fischer, Robert James                Tomargo, J.
# 17               Turner, Abe      Fischer, Robert James
# 18     Fischer, Robert James              Byrne, Donald
# 19     Fischer, Robert James                  Baron, S.
# 20  Reshevsky, Samuel Herman      Fischer, Robert James
# 21               Turner, Abe      Fischer, Robert James
# 22  Bisguier, Arthur Bernard      Fischer, Robert James
# 23     Hearst, Eliot Sanford      Fischer, Robert James
# 24                      draw                       draw
# 25                      draw                       draw
# 26                      draw                       draw
# 27                      draw                       draw
# 28     Fischer, Robert James           Seidman, Herbert
# 29              Nash, Edmund      Fischer, Robert James
# 30     Fischer, Robert James              Grossguth, C.
# 31                      draw                       draw
# 32     Fischer, Robert James                   Ruth, D.
# 33                      draw                       draw
# 34                      draw                       draw
# 35     Fischer, Robert James           Lapiken, Peter P
# 36                      draw                       draw
# 37     Fischer, Robert James                  Swank, A.
# 38                      draw                       draw
# 39     Fischer, Robert James            Popovych, Orest
# 40                      draw                       draw
# 41                      draw                       draw
# 42     Fischer, Robert James          Donovan, Jeremiah
# 43     Fischer, Robert James               Nash, Edmund
# 44     Fischer, Robert James  Marchand, Erich Watkinson
# 45     Fischer, Robert James                  Goldhamer
# 46                      draw                       draw
# 47     Fischer, Robert James        Di Camillo, Attilio
# 48                      draw                       draw
# 49     Fischer, Robert James             Green, Matthew

# %%
df_fisher['date_played'] = pd.to_datetime(df_fisher['date_played'], format='%Y.??.??')
# convierto a formato datetima la columna de fecha, ajusto el formato para mostrar el año, puesto que todas las fechas estan en formato año.??.??

# %%
df_fisher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   event        827 non-null    object
#  1   site         827 non-null    object
#  2   date_played  827 non-null    datetime64[ns]
#  3   white        827 non-null    object
#  4   black        827 non-null    object
#  5   result       827 non-null    object
#  6   white_elo    72 non-null     float64
#  7   black_elo    72 non-null     float64
#  8   winner       827 non-null    object
#  9   loser        827 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 64.7+ KB

# %%
df_fisher['site'].value_counts()
# Out:
# site
# New York                143
# Buenos Aires             47
# ?                        40
# Belgrade                 37
# Mar del Plata            29
# Bled/Zagreb/Belgrade     28
# Curacao                  27
# Reykjavik                25
# Palma de Mallorca        23
# Havana                   22
# Stockholm                22
# Herceg Novi              22
# Portoroz                 20
# Santa Monica             20
# Bled                     19
# Leipzig                  18
# Varna                    17
# Zagreb                   17
# Skopje                   17
# La Habana                17
# Zuerich                  15
# Siegen                   14
# Vinkovci                 13
# Netanya                  13
# Milwaukee                13
# Santiago                 12
# Los Angeles              11
# Cicero                   11
# Sousse                   10
# Davis                    10
# Monte Carlo               9
# Meralco                   8
# Bay City                  8
# Montreal                  8
# East Orange               7
# Washington                6
# Cleveland                 6
# Poughskeepie              6
# Vancouver                 6
# Denver                    6
# West Orange               6
# Athens                    5
# Chicago                   4
# Cambridge                 3
# Hartford                  2
# Solingen                  1
# Davoa                     1
# Copenhagen                1
# Warsaw                    1
# Berlin-West               1
# Name: count, dtype: int64

# %%
df_fisher.to_csv('df_fisher_limpio.csv')
