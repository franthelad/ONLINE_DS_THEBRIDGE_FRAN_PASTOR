# %% [markdown]
# delitos el 15.01.2018 en sql city
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# TESTIGO 1
# ![image.png](attachment:image.png)
# entrevista
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# TESTIGO 2
# ![image.png](attachment:image.png)
# entrevista
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# RASGOS DEL SOSPECHOSO ACORDE A LAS ENTREVISTAS
#
# .- miembro get fit now gym
# .- miembro oro
# .- numero de socio comienza en '48Z%'
# .- matricula de coche contiene 'H42W'
# .- fue visto entrenando en el gym el 09.01.2018

# %% [markdown]
# PRINCIPAL SOSPECHOSO
# ![image.png](attachment:image.png)
# datos del sospechoso
# ![image-2.png](attachment:image-2.png)
# entrevista al sospechoso
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# EL SOSPECHOSO RESULTA SER UN SICARIO
# PISTAS SOBRE QUIEN LE CONTRATO
# .- woman
# .- altura entre 5'5" (65") y 5'7 (67")
# .- pelirroja
# .- conduce un Tesla Model S
# .- acudio 3 veces veces el SQL Symphony Concert en diciembre de 2017

# %% [markdown]
# PRINCIPAL SOSPECHOSA DE CONTRATAR AL SICARIO
# ![image-2.png](attachment:image-2.png)
# corroboramos que la señora ingresa 'lots of money'
# ![image.png](attachment:image.png)
# compruebo si se interrogo a esta señora, pero no fue el caso
# ![image-3.png](attachment:image-3.png)
# la autora del delito fue esta señora
# MIRANDA PRIESTLY
