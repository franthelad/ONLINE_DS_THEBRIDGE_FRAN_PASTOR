# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
train_set = pd.read_csv('./data/train_limpio.csv').drop(['Price_euros'], axis= 1)

# %%
train_set
# Out:
#      Company  Product  TypeName  Inches  ScreenResolution  Cpu  Ram  Memory  \
# 0        4.0    178.0       3.0    15.6               0.0  2.7    8     9.0
# 1        2.0    425.0       3.0    15.6               0.0  1.1    4     9.0
# 2       16.0    258.0       3.0    13.3               3.0  2.3    8    15.0
# 3        4.0     38.0       1.0    15.6              13.0  2.8   16    17.0
# 4        4.0    215.0       4.0    12.5               3.0  2.4    8    15.0
# ..       ...      ...       ...     ...               ...  ...  ...     ...
# 907      0.0     71.0       0.0    11.6               0.0  1.6    4    22.0
# 908     16.0    254.0       3.0    13.3               3.0  2.3    4     3.0
# 909      0.0     53.0       3.0    15.6               0.0  2.2    8     9.0
# 910      4.0    211.0       4.0    14.0               3.0  2.8    8    15.0
# 911      4.0    173.0       3.0    15.6               0.0  2.7    8     9.0
#
#      Gpu  OpSys  Weight
# 0    0.0    5.0    2.36
# ...

# %%
for i in train_set.columns:
    sns.boxplot(train_set[i])
    plt.show()

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')

train_set_imputed = imputer.fit_transform(train_set)

# %%
train_set_imputed = pd.DataFrame(train_set_imputed, columns= train_set.columns, index= train_set.index)

# %%
for i in train_set_imputed.columns:
    sns.boxplot(train_set_imputed[i])
    plt.show()
