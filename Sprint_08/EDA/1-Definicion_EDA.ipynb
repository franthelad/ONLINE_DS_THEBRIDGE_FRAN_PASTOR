# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Ajedrez, mejores jugadores y contexto historico."

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = """
Mi idea es realizar un estudio sobre los jugadores de ajedrez registrados en FIDE y estudiar mejores jugadores por federeciones, edad, etc.
Ademas planteo estudiar algunos de los principales jugadores historicos y su relevancia en su epoca. Tengo entendido que durante la guerra fria hubo una rivalidad intensa entre
los dos bloques, quisiera estudiar sus jugadores y ver que resultados interesantes encuentro, como cantidad de torneos, victorias o trampas.
"""

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = " Comparativas de jugadores"

hipotesis_2 = 'mejores jugadores por federaciones, edad'

hipotesis_3 = 'correlacion games/ELO'

hipotesis_provisional= "Hubo un auge del ajedrez durante la guerra fria promovido por los principales bloques y la rivalidad entre estos."

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = ""
# hipotesis_3 = ""
# hipotesis_4 = ""
# hipotesis_5 = ""
# ...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente

#HASTA EL MOMENTO TODOS LOS CSVs QUE HE CONSEGUIDO PROVIENEN DE FIDE y KAGGLE, NO OBSTANTE AUN ESTOY BUSCANDO MAS INFO Y ESTA LISTA NO ES FINAL

df_carlsen = pd.read_csv('./data/carlsen/Carlsen_game_info.csv') # estas tengo que estudiarlas mas a fondo, no terminan de convencerme, tengo otras en el back up
df_fisher = pd.read_csv('./data/fisher/fischer_game_info.csv')
df_kasparov = pd.read_csv('./data/kasparov_76_21/Kasparov_game_info.csv')
df_nakamura = pd.read_csv('./data/nakamura/Nakamura_game_info.csv') # estas tengo que estudiarlas mas a fondo, no terminan de convencerme, tengo otras en el back up
df_titled = pd.read_csv('./data/data_20000p_2021/chess_titled_players.csv')
df_rating = pd.read_csv('./data/data_20000p_2021/players_rating.csv')
df_activos = pd.read_csv('./data/data_fide/fide_active_players_2023.csv')
# copablanca, estudiar su apertura (personal)
# Boris Spassky
# 1972 world championship
# bernabeu
# gothan
# anna cramling
# fran

# sumo econometrics buscar info

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
print(df_carlsen.info())
df_carlsen.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4314 entries, 0 to 4313
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   game_id                4314 non-null   object
#  1   game_order             4314 non-null   int64
#  2   event                  4314 non-null   object
#  3   site                   4314 non-null   object
#  4   date_played            4314 non-null   object
#  5   round                  4314 non-null   object
#  6   white                  4314 non-null   object
#  7   black                  4314 non-null   object
#  8   result                 4314 non-null   object
#  9   white_elo              4293 non-null   float64
#  10  white_rating_diff      0 non-null      float64
#  11  black_elo              4280 non-null   float64
#  12  black_rating_diff      0 non-null      float64
#  13  white_title            0 non-null      float64
# ...

# %%
print(df_fisher.info())
df_fisher.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   game_id                827 non-null    object
#  1   game_order             827 non-null    int64
#  2   event                  827 non-null    object
#  3   site                   827 non-null    object
#  4   date_played            827 non-null    object
#  5   round                  827 non-null    object
#  6   white                  827 non-null    object
#  7   black                  827 non-null    object
#  8   result                 827 non-null    object
#  9   white_elo              72 non-null     float64
#  10  black_elo              72 non-null     float64
#  11  winner                 827 non-null    object
#  12  winner_elo             43 non-null     float64
#  13  loser                  827 non-null    object
# ...

# %%
print(df_kasparov.info())
df_kasparov.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2128 entries, 0 to 2127
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   game_id                2128 non-null   object
#  1   game_order             2128 non-null   int64
#  2   event                  2128 non-null   object
#  3   site                   2128 non-null   object
#  4   date_played            2128 non-null   object
#  5   round                  2128 non-null   object
#  6   white                  2128 non-null   object
#  7   black                  2128 non-null   object
#  8   result                 2128 non-null   object
#  9   white_elo              2057 non-null   object
#  10  black_elo              1851 non-null   object
#  11  winner                 2128 non-null   object
#  12  winner_elo             1217 non-null   object
#  13  loser                  2128 non-null   object
# ...

# %%
print(df_nakamura.info())
df_nakamura.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   game_id                4812 non-null   object
#  1   game_order             4812 non-null   int64
#  2   event                  4812 non-null   object
#  3   site                   4812 non-null   object
#  4   date_played            4812 non-null   object
#  5   round                  4812 non-null   object
#  6   white                  4812 non-null   object
#  7   black                  4812 non-null   object
#  8   result                 4812 non-null   object
#  9   white_elo              4782 non-null   float64
#  10  black_elo              4769 non-null   float64
#  11  winner                 4812 non-null   object
#  12  winner_elo             3070 non-null   float64
#  13  loser                  4812 non-null   object
# ...

# %%
print(df_activos.info())
df_activos.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4996 entries, 0 to 4995
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             4996 non-null   object
#  1   Title            4996 non-null   object
#  2   Country          4996 non-null   object
#  3   Standard Rating  4996 non-null   float64
#  4   Rapid Rating     4322 non-null   float64
#  5   Blitz Rating     4327 non-null   float64
#  6   Birth Year       4996 non-null   float64
#  7   Age              4996 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 312.4+ KB
# None
#                Name Title        Country  Standard Rating  Rapid Rating  \
# 0   Carlsen, Magnus    GM         Norway           2829.0        2818.0
# 1  Caruana, Fabiano    GM  United States           2795.0        2765.0
# 2       Ding, Liren    GM          China           2780.0        2830.0
#
#    Blitz Rating  Birth Year   Age
# ...

# %%
print(df_titled.info())
df_titled.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19509 entries, 0 to 19508
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        19509 non-null  int64
#  1   id                                19509 non-null  int64
#  2   name                              19509 non-null  object
#  3   title                             19509 non-null  object
#  4   woman_title                       3928 non-null   object
#  5   country                           19509 non-null  object
#  6   classical                         19435 non-null  float64
#  7   rapid                             11811 non-null  float64
#  8   blitz                             12074 non-null  float64
#  9   birth_year                        19507 non-null  float64
#  10  sex                               19509 non-null  object
# ...

# %%
print(df_rating.info())
print(df_rating.isnull().sum())
df_rating.head(3)
# muchos nulos en este data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2835829 entries, 0 to 2835828
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   id               int64
#  1   date             object
#  2   classical elo    float64
#  3   classical games  float64
#  4   rapid elo        float64
#  5   rapid games      float64
#  6   blitz elo        float64
#  7   blitz games      float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 173.1+ MB
# None
# id                       0
# date                     0
# classical elo        11542
# classical games      11542
# rapid elo          1856267
# rapid games        1856267
# blitz elo          1839393
# blitz games        1839393
# dtype: int64
#         id        date  classical elo  classical games  rapid elo  \
# 0  4611870  2021-09-01         2290.0              0.0        NaN
# 1  4611870  2021-08-01         2290.0              0.0        NaN
# ...

# %% [markdown]
# toda esta info es aun provisional, es susceptible de modificar datasets y utilizar otros que encuentre mas completos, hay que limpiarlos, seleccionar info relevante y comprobar que la info que puedo recaudar aqui encaja con mis hipotesis y objetivos.
#
# Incluso los objetivos son susceptibles de modificacion.
